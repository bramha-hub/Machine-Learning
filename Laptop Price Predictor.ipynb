# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df['Ram']=df[['Ram']].astype(int)

# %%
df['Weight']=df[['Weight']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(df['Price'])

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Inches'])

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: ScreenResolution, dtype: int64

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(10)
# Out:
#        Company            TypeName  Inches  \
# 670  Microsoft           Ultrabook    13.5
# 68      Lenovo            Notebook    15.6
# 696     Lenovo  2 in 1 Convertible    14.0
# 968       Dell              Gaming    17.3
# 250       Dell  2 in 1 Convertible    15.6
# 160       Asus            Notebook    15.6
# 588     Lenovo            Notebook    15.6
# 113         HP            Notebook    14.0
# 726       Dell            Notebook    15.6
# 802       Dell           Ultrabook    13.3
#
#                               ScreenResolution                          Cpu  \
# 670                      Touchscreen 2256x1504   Intel Core i7 7600U 2.8GHz
# 68                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 696            Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 968                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 250  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 8550U 1.8GHz
# 160                                   1366x768      AMD A9-Series 9420 3GHz
# 588                       Touchscreen 1366x768   Intel Core i7 8550U 1.8GHz
# 113                         IPS Panel 1366x768   Intel Core i5 8250U 1.6GHz
# 726                          Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
# 802                          Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
#
#      Ram                Memory                           Gpu         OpSys  \
# 670    8             256GB SSD  Intel Iris Plus Graphics 640  Windows 10 S
# 68     4               1TB HDD         Intel HD Graphics 620    Windows 10
# 696   16             512GB SSD         Intel HD Graphics 620    Windows 10
# 968   32  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070    Windows 10
# 250    8               1TB HDD        Intel UHD Graphics 620    Windows 10
# 160    4               1TB HDD            AMD Radeon R5 M420    Windows 10
# 588   12               1TB HDD         Intel HD Graphics 620    Windows 10
# 113    4             500GB HDD        Intel UHD Graphics 620    Windows 10
# 726    8  128GB SSD +  1TB HDD                AMD Radeon 530    Windows 10
# 802    8             256GB SSD         Intel HD Graphics 620    Windows 10
#
#      Weight       Price  TouchScreen
# 670   1.252   99519.048            1
# 68    1.900   29250.720            0
# 696   1.380   93186.720            1
# 968   4.420  167778.720            0
# 250   2.080   43636.320            1
# 160   2.030   21471.840            0
# 588   2.200   32447.520            1
# 113   1.630   38468.160            0
# 726   2.200   38308.320            0
# 802   1.290   79866.720            0

# %%
df['TouchScreen'].value_counts()
# Out:
# 0    1111
# 1     192
# Name: TouchScreen, dtype: int64

# %%
sns.barplot(x=df['TouchScreen'],y=df['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df['IPS panel'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS panel
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1

# %%
sns.barplot(x=df['IPS panel'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS panel', ylabel='Price'>

# %%
df['IPS panel'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS panel                          X_res Y_res
# 0          1  IPS Panel Retina Display 2560  1600
# 1          0                           1440   900
# 2          0                   Full HD 1920  1080
# 3          1  IPS Panel Retina Display 2880  1800
# 4          1  IPS Panel Retina Display 2560  1600

# %%
# df['X_res']=df['X_res'].apply(lambda x:df['X_res'][i][-4:])
df['X_res']=[i[-4:] for i in df['X_res']]

# %%
df.sample(10)
# Out:
#     Company            TypeName  Inches                 ScreenResolution  \
# 297    Dell         Workstation    17.3                Full HD 1920x1080
# 809  Lenovo            Notebook    15.6                Full HD 1920x1080
# 775    Asus  2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 44     Dell  2 in 1 Convertible    17.3  Full HD / Touchscreen 1920x1080
# 951    Dell           Ultrabook    14.0                Full HD 1920x1080
# 915  Lenovo            Notebook    13.3                Full HD 1920x1080
# 168    Acer            Notebook    17.3      IPS Panel Full HD 1920x1080
# 703  Lenovo            Notebook    15.6                Full HD 1920x1080
# 635    Asus            Notebook    15.6                Full HD 1920x1080
# 532    Asus            Notebook    15.6  IPS Panel 4K Ultra HD 3840x2160
#
#                              Cpu  Ram                Memory  \
# 297  Intel Core i7 7820HQ 2.9GHz   16             256GB SSD
# 809   Intel Core i5 7200U 2.5GHz    4               1TB HDD
# 775   Intel Core i7 7500U 2.7GHz   12               2TB HDD
# 44    Intel Core i5 8250U 1.6GHz   12               1TB HDD
# 951   Intel Core i7 7600U 2.8GHz    8             256GB SSD
# 915   Intel Core i5 7200U 2.5GHz    4             128GB SSD
# 168   Intel Core i5 8250U 1.6GHz    8             256GB SSD
# 703   Intel Core i5 7200U 2.5GHz    4    1TB HDD +  1TB HDD
# 635  Intel Core i5 7300HQ 2.5GHz    8               1TB HDD
# 532   Intel Core i7 7500U 2.7GHz    8  256GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight        Price  TouchScreen  \
# 297      Nvidia Quadro M1200  Windows 10    3.42  153705.3408            0
# 809      Nvidia GeForce 920M  Windows 10    2.40   32447.5200            0
# 775     Nvidia GeForce 940MX  Windows 10    2.30   44701.9200            1
# 44      Nvidia GeForce 150MX  Windows 10    2.77   53226.7200            1
# 951    Intel HD Graphics 620  Windows 10    1.36   94572.0000            0
# 915    Intel HD Graphics 620  Windows 10    1.44   46939.6800            0
# 168     Nvidia GeForce MX150  Windows 10    3.00   45501.1200            0
# 703    Intel HD Graphics 620  Windows 10    2.10   33110.8560            0
# 635  Nvidia GeForce GTX 1050  Windows 10    1.99   48304.7136            0
# 532  Nvidia GeForce GTX 960M  Windows 10    2.00   69210.7200            0
#
#      IPS panel X_res Y_res
# 297          0  1920  1080
# 809          0  1920  1080
# 775          0  1920  1080
# 44           0  1920  1080
# 951          0  1920  1080
# 915          0  1920  1080
# 168          1  1920  1080
# 703          0  1920  1080
# 635          0  1920  1080
# 532          1  3840  2160

# %%
df['X_res']=df['X_res'].astype(int)

# %%
df['Y_res']=df['Y_res'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS panel         1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# memory usage: 137.6+ KB

# %%
df.corr()['Price']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['PPI']=((((df['X_res']**2) + (df['Y_res']**2))**0.5)/df['Inches']).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  IPS panel         1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
#  15  PPI               1303 non-null   float64
# dtypes: float64(4), int32(3), int64(2), object(7)
# memory usage: 147.7+ KB

# %%
df.corr()['Price']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# IPS panel      0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.sample(10)
# Out:
#      Company            TypeName                           ScreenResolution  \
# 980     Dell  2 in 1 Convertible  IPS Panel Full HD / Touchscreen 1920x1080
# 877   Xiaomi           Ultrabook                IPS Panel Full HD 1920x1080
# 690     Acer            Notebook                                   1366x768
# 1227    Dell            Notebook                                   1366x768
# 616     Dell            Notebook                          Full HD 1920x1080
# 455     Dell  2 in 1 Convertible                       Touchscreen 1366x768
# 118     Asus            Notebook                          Full HD 1920x1080
# 61      Dell           Ultrabook                          Full HD 1920x1080
# 230     Asus            Notebook                                   1366x768
# 493     Acer            Notebook                                   1366x768
#
#                                        Cpu  Ram              Memory  \
# 980             Intel Core i7 7500U 2.7GHz   12           512GB SSD
# 877             Intel Core i5 6200U 2.3GHz    8           256GB SSD
# 690   Intel Celeron Dual Core 3855U 1.6GHz    4  32GB Flash Storage
# 1227            Intel Core i5 7200U 2.5GHz    4             1TB HDD
# 616             Intel Core i5 7200U 2.5GHz    4           128GB SSD
# 455   Intel Pentium Quad Core N3710 1.6GHz    4           500GB HDD
# 118               Intel Core i3 6006U 2GHz    4             1TB HDD
# 61              Intel Core i5 8250U 1.6GHz    8           256GB SSD
# 230             Intel Core i3 7100U 2.4GHz    4             1TB HDD
# 493            AMD A10-Series 9620P 2.5GHz    8             1TB HDD
#
#                          Gpu       OpSys  Weight       Price  TouchScreen  \
# 980    Intel HD Graphics 620  Windows 10    2.19  69210.7200            1
# 877     Nvidia GeForce 940MX  Windows 10    1.28  49816.8000            0
# 690    Intel HD Graphics 510   Chrome OS    1.45  19980.0000            0
# 1227   Intel HD Graphics 520       Linux    2.18  27804.7008            0
# 616       AMD Radeon R5 M420       Linux    2.18  30316.3200            0
# 455    Intel HD Graphics 405  Windows 10    1.47  25521.1200            1
# 118     Nvidia GeForce 920MX  Windows 10    2.00  30049.9200            0
# 61    Intel UHD Graphics 620  Windows 10    1.70  46833.1200            0
# 230    Intel HD Graphics 620  Windows 10    2.37  21258.1872            0
# 493        AMD Radeon RX 540  Windows 10    2.20  30849.1200            0
#
#       IPS panel         PPI
# 980           1  141.211998
# 877           1  165.632118
# 690           0  111.935204
# 1227          0  100.454670
# 616           0  141.211998
# 455           0  135.094211
# 118           0  127.335675
# 61            0  157.350512
# 230           0  100.454670
# 493           0  100.454670

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['cpu_type']=df['Cpu'].apply(lambda x:" ".join(x.split()[:3]))

# %%
df.sample(10)
# Out:
#      Company   TypeName             ScreenResolution  \
# 1214    Asus     Gaming            Full HD 1920x1080
# 198       HP     Gaming  IPS Panel Full HD 1920x1080
# 678       LG  Ultrabook  IPS Panel Full HD 1920x1080
# 394     Dell   Notebook            Full HD 1920x1080
# 572       HP   Notebook  IPS Panel Full HD 1920x1080
# 702   Lenovo   Notebook                     1366x768
# 43      Acer   Notebook  IPS Panel Full HD 1920x1080
# 136   Lenovo   Notebook                     1366x768
# 78      Acer   Notebook            Full HD 1920x1080
# 326     Acer   Notebook                     1366x768
#
#                                        Cpu  Ram                Memory  \
# 1214           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 198            Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 678             Intel Core i7 8550U 1.8GHz    8             512GB SSD
# 394             Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 572             AMD A9-Series A9-9420 3GHz    6             256GB SSD
# 702            AMD A12-Series 9720P 3.6GHz    8               1TB HDD
# 43              Intel Core i5 8250U 1.6GHz    4             256GB SSD
# 136   Intel Celeron Dual Core N3350 1.1GHz    4               1TB HDD
# 78              Intel Core i3 7130U 2.7GHz    4               1TB HDD
# 326             Intel Core i5 7200U 2.5GHz    6               1TB HDD
#
#                           Gpu       OpSys  Weight        Price  TouchScreen  \
# 1214  Nvidia GeForce GTX 1060  Windows 10    2.90  103842.7200            0
# 198   Nvidia GeForce GTX 1050  Windows 10    3.35   73473.1200            0
# 678     Intel HD Graphics 620  Windows 10    1.09  122490.7200            0
# 394        AMD Radeon R7 M445       Linux    2.33   41498.1936            0
# 572            AMD Radeon 530  Windows 10    1.95   34578.7200            0
# 702             AMD Radeon R7  Windows 10    2.20   22857.1200            0
# 43     Intel UHD Graphics 620  Windows 10    2.20   36336.9600            0
# 136     Intel HD Graphics 500       No OS    1.90   13445.7408            0
# 78       Nvidia GeForce MX130  Windows 10    2.20   28238.4000            0
# 326     Intel HD Graphics 620  Windows 10    2.23   29250.7200            0
#
#       IPS panel         PPI               cpu_type
# 1214          0  127.335675          Intel Core i7
# 198           1  127.335675          Intel Core i7
# 678           1  141.211998          Intel Core i7
# 394           0  141.211998          Intel Core i7
# 572           1  141.211998  AMD A9-Series A9-9420
# 702           0  100.454670   AMD A12-Series 9720P
# 43            1  141.211998          Intel Core i5
# 136           0  100.454670     Intel Celeron Dual
# 78            0  141.211998          Intel Core i3
# 326           0  100.454670          Intel Core i5

# %%
def fetch_process(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0]=='Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD processor'

# %%
df['CPU brand'] = df['cpu_type'].apply(fetch_process)

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook                            1440x900
# 2      HP   Notebook                   Full HD 1920x1080
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0
#
#    IPS panel         PPI       cpu_type      CPU brand
# 0          1  226.983005  Intel Core i5  Intel Core i5
# 1          0  127.677940  Intel Core i5  Intel Core i5
# 2          0  141.211998  Intel Core i5  Intel Core i5
# 3          1  220.534624  Intel Core i7  Intel Core i7
# 4          1  226.983005  Intel Core i5  Intel Core i5

# %%
df['CPU brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['CPU brand'],y=df['Price'])
# Out:
# <Axes: xlabel='CPU brand', ylabel='Price'>

# %%
df.drop(columns=['Cpu','cpu_type'],inplace=True)

# %%
df.sample(10)
# Out:
#     Company            TypeName                 ScreenResolution  Ram  \
# 82       HP            Notebook                Full HD 1920x1080    8
# 801    Asus            Notebook                Full HD 1920x1080    8
# 734  Lenovo            Notebook      IPS Panel Full HD 1920x1080    8
# 412      HP            Notebook                Full HD 1920x1080    4
# 206    Dell            Notebook             Touchscreen 1366x768    6
# 213  Lenovo            Notebook                Full HD 1920x1080    8
# 848      HP  2 in 1 Convertible  Full HD / Touchscreen 1920x1080    8
# 781    Asus              Gaming      IPS Panel Full HD 1920x1080   16
# 324    Acer            Notebook                         1366x768    8
# 359    Dell            Notebook                Full HD 1920x1080    8
#
#                    Memory                      Gpu       OpSys  Weight  \
# 82              256GB SSD    Intel HD Graphics 620  Windows 10    1.63
# 801             256GB SSD    Intel HD Graphics 620  Windows 10    2.37
# 734             256GB SSD    Intel HD Graphics 620  Windows 10    1.44
# 412               1TB HDD           AMD Radeon 520  Windows 10    2.10
# 206               1TB HDD    Intel HD Graphics 620  Windows 10    2.30
# 213             256GB SSD    Intel HD Graphics 620       No OS    2.20
# 848             256GB SSD    Intel HD Graphics 620  Windows 10    1.28
# 781  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10    4.30
# 324             256GB SSD        AMD Radeon RX 540  Windows 10    2.20
# 359             256GB SSD    Intel HD Graphics 620  Windows 10    1.36
#
#          Price  TouchScreen  IPS panel         PPI      CPU brand
# 82    45820.80            0          0  157.350512  Intel Core i5
# 801   58554.72            0          0  141.211998  Intel Core i5
# 734   51148.80            0          1  165.632118  Intel Core i5
# 412   24988.32            0          0  141.211998  Intel Core i3
# 206   23389.92            1          0  100.454670  Intel Core i3
# 213   29250.72            0          0  141.211998  Intel Core i5
# 848  121318.56            1          0  165.632118  Intel Core i5
# 781  125208.00            0          1  127.335675  Intel Core i7
# 324   35111.52            0          0  100.454670  AMD processor
# 359   76030.56            0          0  157.350512  Intel Core i5

# %%
df['Ram'].value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
# plt.xticks(rotation='vertical')
# plt.show()
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
df['Memory']=df['Memory'].astype(str).replace('\.0','',regex=True)

# %%
df.sample(10)
# Out:
#      Company   TypeName                           ScreenResolution  Ram  \
# 844       HP  Ultrabook                          Full HD 1920x1080    8
# 901     Asus     Gaming                IPS Panel Full HD 1920x1080   32
# 524     Dell   Notebook                IPS Panel Full HD 1920x1080    8
# 404      MSI     Gaming                          Full HD 1920x1080   16
# 397   Lenovo   Notebook                IPS Panel Full HD 1920x1080    8
# 1008      HP   Notebook                          Full HD 1920x1080    8
# 815   Lenovo  Ultrabook                          Full HD 1920x1080    8
# 212       HP   Notebook                          Full HD 1920x1080    4
# 813     Dell   Notebook                          Full HD 1920x1080    8
# 510     Dell  Ultrabook  IPS Panel Full HD / Touchscreen 1920x1080    8
#
#                    Memory                      Gpu       OpSys  Weight  \
# 844               512 SSD    Intel HD Graphics 520   Windows 7    1.54
# 901    256 SSD +  256 SSD  Nvidia GeForce GTX 980M  Windows 10    3.58
# 524   128 SSD +  1000 HDD           AMD Radeon 530       Linux    2.80
# 404   256 SSD +  1000 HDD  Nvidia GeForce GTX 1070  Windows 10    2.80
# 397               256 SSD    Intel HD Graphics 620  Windows 10    1.90
# 1008              256 SSD     Nvidia GeForce 930MX  Windows 10    1.64
# 815               256 SSD    Intel HD Graphics 620  Windows 10    1.32
# 212               500 HDD    Intel HD Graphics 520       No OS    2.10
# 813              1000 HDD  Nvidia GeForce GT 940MX  Windows 10    1.98
# 510               128 SSD    Intel HD Graphics 620  Windows 10    1.29
#
#             Price  TouchScreen  IPS panel         PPI      CPU brand
# 844    99633.6000            0          0  157.350512  Intel Core i7
# 901    68145.1200            0          1  127.335675  Intel Core i7
# 524    47365.9200            0          1  127.335675  Intel Core i5
# 404   119826.7200            0          0  127.335675  Intel Core i7
# 397    49976.6400            0          1  157.350512  Intel Core i5
# 1008   55904.5728            0          0  157.350512  Intel Core i5
# 815    99047.5200            0          0  157.350512  Intel Core i7
# 212    18594.7200            0          0  141.211998  Intel Core i3
# 813    51202.0800            0          0  141.211998  Intel Core i7
# 510    47898.7200            1          1  165.632118  Intel Core i5

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\4023190604.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\4023190604.py:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company   TypeName                    ScreenResolution  Ram  \
# 0   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
# 1   Apple  Ultrabook                            1440x900    8
# 2      HP   Notebook                   Full HD 1920x1080    8
# 3   Apple  Ultrabook  IPS Panel Retina Display 2880x1800   16
# 4   Apple  Ultrabook  IPS Panel Retina Display 2560x1600    8
#
#               Memory                           Gpu  OpSys  Weight  \
# 0            128 SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128 Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256 SSD         Intel HD Graphics 620  No OS    1.86
# 3            512 SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256 SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS panel         PPI      CPU brand  layer11hdd  \
# 0   71378.6832            0          1  226.983005  Intel Core i5           0
# 1   47895.5232            0          0  127.677940  Intel Core i5           0
# 2   30636.0000            0          0  141.211998  Intel Core i5           0
# 3  135195.3360            0          1  220.534624  Intel Core i7           0
# 4   96095.8080            0          1  226.983005  Intel Core i5           0
#
#    HDD  SSD  Hybrid  Flash_Storage
# 0    0  128       0              0
# 1    0    0       0            128
# 2    0  256       0              0
# 3    0  512       0              0
# 4    0  256       0              0

# %%
# df.drop(columns=['layer11hdd'],inplace=True)

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  IPS panel         PPI  \
# 0  macOS    1.37   71378.6832            0          1  226.983005
# 1  macOS    1.34   47895.5232            0          0  127.677940
# 2  No OS    1.86   30636.0000            0          0  141.211998
# 3  macOS    1.83  135195.3360            0          1  220.534624
# 4  macOS    1.37   96095.8080            0          1  226.983005
#
#        CPU brand  HDD  SSD  Hybrid  Flash_Storage
# 0  Intel Core i5    0  128       0              0
# 1  Intel Core i5    0    0       0            128
# 2  Intel Core i5    0  256       0              0
# 3  Intel Core i7    0  512       0              0
# 4  Intel Core i5    0  256       0              0

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.corr()['Price']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\815546952.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# IPS panel        0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  IPS panel         PPI      CPU brand  HDD  SSD
# 0   71378.6832            0          1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0          0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0          0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0          1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0          1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0] )

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu  OpSys  Weight        Price  TouchScreen  \
# 0   Apple  Ultrabook    8  Intel  macOS    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  Intel  macOS    1.34   47895.5232            0
# 2      HP   Notebook    8  Intel  No OS    1.86   30636.0000            0
# 3   Apple  Ultrabook   16    AMD  macOS    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  Intel  macOS    1.37   96095.8080            0
#
#    IPS panel         PPI      CPU brand  HDD  SSD
# 0          1  226.983005  Intel Core i5    0  128
# 1          0  127.677940  Intel Core i5    0    0
# 2          0  141.211998  Intel Core i5    0  256
# 3          1  220.534624  Intel Core i7    0  512
# 4          1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu, dtype: int64

# %%
df=(df[df['Gpu']!='ARM'])

# %%
df['Gpu'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu, dtype: int64

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
def cat_os(inp):
    if inp=='Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others'

# %%
df['OpSys']=df['OpSys'].apply(cat_os)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\444854395.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OpSys']=df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram    Gpu   OpSys  Weight        Price  TouchScreen  \
# 0   Apple  Ultrabook    8  Intel     Mac    1.37   71378.6832            0
# 1   Apple  Ultrabook    8  Intel     Mac    1.34   47895.5232            0
# 2      HP   Notebook    8  Intel  Others    1.86   30636.0000            0
# 3   Apple  Ultrabook   16    AMD     Mac    1.83  135195.3360            0
# 4   Apple  Ultrabook    8  Intel     Mac    1.37   96095.8080            0
#
#    IPS panel         PPI      CPU brand  HDD  SSD
# 0          1  226.983005  Intel Core i5    0  128
# 1          0  127.677940  Intel Core i5    0    0
# 2          0  141.211998  Intel Core i5    0  256
# 3          1  220.534624  Intel Core i7    0  512
# 4          1  226.983005  Intel Core i5    0  256

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Weight'])

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17008\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.displot(np.log(df['Price']))

# %%
x=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
x.head()
# Out:
#   Company   TypeName  Ram    Gpu   OpSys  Weight  TouchScreen  IPS panel  \
# 0   Apple  Ultrabook    8  Intel     Mac    1.37            0          1
# 1   Apple  Ultrabook    8  Intel     Mac    1.34            0          0
# 2      HP   Notebook    8  Intel  Others    1.86            0          0
# 3   Apple  Ultrabook   16    AMD     Mac    1.83            0          1
# 4   Apple  Ultrabook    8  Intel     Mac    1.37            0          1
#
#           PPI      CPU brand  HDD  SSD
# 0  226.983005  Intel Core i5    0  128
# 1  127.677940  Intel Core i5    0    0
# 2  141.211998  Intel Core i5    0  256
# 3  220.534624  Intel Core i7    0  512
# 4  226.983005  Intel Core i5    0  256

# %%
y.head()
# Out:
# 0    11.175755
# 1    10.776777
# 2    10.329931
# 3    11.814476
# 4    11.473101
# Name: Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.sample(10)
# Out:
#      Company            TypeName  Ram     Gpu    OpSys  Weight  TouchScreen  \
# 456     Dell            Notebook    8  Nvidia  Windows    4.42            0
# 476     Dell         Workstation    8  Nvidia  Windows    1.78            0
# 754     Asus            Notebook    4   Intel  Windows    2.37            0
# 891       HP  2 in 1 Convertible   16   Intel  Windows    1.42            1
# 13      Dell            Notebook    4     AMD  Windows    2.20            0
# 439     Asus            Notebook    4   Intel   Others    2.00            0
# 475     Dell            Notebook    8   Intel  Windows    1.79            0
# 384     Asus           Ultrabook   16   Intel  Windows    1.10            1
# 1136      HP         Workstation    8  Nvidia  Windows    3.00            0
# 861       HP            Notebook    8     AMD  Windows    1.84            0
#
#       IPS panel         PPI      CPU brand   HDD  SSD
# 456           1  127.335675  Intel Core i7  1000    0
# 476           0  141.211998  Intel Core i7     0  256
# 754           0  100.454670  Intel Core i7     0  256
# 891           0  276.053530  Intel Core i7     0  256
# 13            0  141.211998  Intel Core i3     0  256
# 439           0  141.211998  Intel Core i5     0  256
# 475           0  111.935204  Intel Core i3     0  128
# 384           0  165.632118  Intel Core i7     0  512
# 1136          1  127.335675  Intel Core i7     0  256
# 861           0  141.211998  Intel Core i5     0  256

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Linear Regressor

# %%
step1=ColumnTransformer(transformers=[
   ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[0,1,3,4,9])    

],remainder='passthrough')

step2=LinearRegression()

pipe=Pipeline([
   ('step1',step1),
   ('step2',step2)

])

pipe.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 3, 4, 9])])),
#                 ('step2', LinearRegression())])

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
y_pred=pipe.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.8407099085992704
# 0.06137346376569461

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Random Forest Regressor

# %%
step1=ColumnTransformer(transformers=[
   ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[0,1,3,4,9])    

],remainder='passthrough')

step2=RandomForestRegressor()

pipe2=Pipeline([
   ('step1',step1),
   ('step2',step2)

])

pipe2.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 3, 4, 9])])),
#                 ('step2', RandomForestRegressor())])

# %%
y_pred2=pipe2.predict(x_test)
print(r2_score(y_test,y_pred2))
print(mean_squared_error(y_test,y_pred2))
# Out:
# 0.8762417548934885
# 0.047683268337402974

# %% [markdown]
# # Decision Tree Regressor

# %%
step1=ColumnTransformer(transformers=[
   ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[0,1,3,4,9])    

],remainder='passthrough')

step2=DecisionTreeRegressor()

pipe3=Pipeline([
   ('step1',step1),
   ('step2',step2)

])

pipe3.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 3, 4, 9])])),
#                 ('step2', DecisionTreeRegressor())])

# %%
y_pred3=pipe3.predict(x_test)
print(mean_squared_error(y_test,y_pred3))
print(r2_score(y_test,y_pred3))
# Out:
# 0.058759297127412354
# 0.8474947764753684
