# %% [markdown]
# Name : Bramha Nimbalkar
#
# Roll no : 7
#
# Div : E

# %%
import pandas as pd

# %%
df = pd.read_csv('ToyotaCorolla.csv')

# %%
df.sample(10)
# Out:
#           Id                                              Model    Price  \
# 1280  1287.0   TOYOTA Corolla 1.3 SDN LINEA TERRA AUT 4/5-Doors   8450.0
# 841    845.0              TOYOTA Corolla 3drs 13i-16V 2/3-Doors   8800.0
# 1286  1293.0  TOYOTA Corolla 1.6 16V LIFTB LINEA LUNA 4/5-Doors   7950.0
# 1173  1179.0  TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA 4/5-D...   6950.0
# 260    262.0  TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3-...  11950.0
# 96      97.0  ?TOYOTA Corolla 1.4 16V VVT I 3DR TERRA COMFOR...  15950.0
# 1332  1339.0  TOYOTA Corolla 1.6 16V SEDAN LINEA TERRA 4/5-D...   8495.0
# 807    811.0  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7950.0
# 472    475.0  TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3-...   9950.0
# 804    808.0                   TOYOTA Corolla 1.3 16V 2/3-Doors   8900.0
#
#       Age_08_04  Mfg_Month  Mfg_Year       KM Fuel_Type     HP  Met_Color  \
# 1280       78.0        3.0    1998.0  73638.0    Petrol   86.0        1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1428 non-null   float64
#  1   Model             1416 non-null   object
#  2   Price             1413 non-null   float64
#  3   Age_08_04         1399 non-null   float64
#  4   Mfg_Month         1398 non-null   float64
#  5   Mfg_Year          1391 non-null   float64
#  6   KM                1384 non-null   float64
#  7   Fuel_Type         1382 non-null   object
#  8   HP                1394 non-null   float64
#  9   Met_Color         1402 non-null   float64
#  10  Automatic         1417 non-null   float64
#  11  cc                1404 non-null   float64
#  12  Doors             1421 non-null   float64
#  13  Cylinders         1412 non-null   float64
#  14  Gears             1420 non-null   float64
#  15  Quarterly_Tax     1409 non-null   float64
# ...

# %%
df1=df.drop(['BOVAG_Guarantee', 'Mfr_Guarantee','Guarantee_Period','Airco','CD_Player','Automatic_airco','Boardcomputer','Powered_Windows','Central_Lock','Power_Steering','Radio','Mistlamps','Sport_Model','Backseat_Divider','Metallic_Rim','Radio_cassette','Tow_Bar'], axis=1)

# %%
df1.head()
# Out:
#     Id                                           Model    Price  Age_08_04  \
# 0  1.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500.0       23.0
# 1  2.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750.0       23.0
# 2  3.0  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950.0       24.0
# 3  4.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950.0       26.0
# 4  5.0     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750.0       30.0
#
#    Mfg_Month  Mfg_Year       KM Fuel_Type    HP  Met_Color  Automatic      cc  \
# 0       10.0    2002.0  46986.0    Diesel  90.0        1.0        0.0  2000.0
# 1       10.0    2002.0  72937.0    Diesel  90.0        1.0        0.0  2000.0
# 2        9.0    2002.0  41711.0    Diesel  90.0        1.0        0.0  2000.0
# 3        7.0    2002.0  48000.0    Diesel  90.0        0.0        0.0  2000.0
# 4        3.0    2002.0  38500.0    Diesel  90.0        0.0        0.0  2000.0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1428 non-null   float64
#  1   Model          1416 non-null   object
#  2   Price          1413 non-null   float64
#  3   Age_08_04      1399 non-null   float64
#  4   Mfg_Month      1398 non-null   float64
#  5   Mfg_Year       1391 non-null   float64
#  6   KM             1384 non-null   float64
#  7   Fuel_Type      1382 non-null   object
#  8   HP             1394 non-null   float64
#  9   Met_Color      1402 non-null   float64
#  10  Automatic      1417 non-null   float64
#  11  cc             1404 non-null   float64
#  12  Doors          1421 non-null   float64
#  13  Cylinders      1412 non-null   float64
#  14  Gears          1420 non-null   float64
#  15  Quarterly_Tax  1409 non-null   float64
#  16  Weight         1414 non-null   float64
# ...

# %%
df1=df1.rename(columns={"id": "ID",'Age_08_04':'Age','Mfg_Month':'Mfg-M','Mfg_Year':'Mfg-Y'})

# %%
df1.head()
# Out:
#     Id                                           Model    Price   Age  Mfg-M  \
# 0  1.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500.0  23.0   10.0
# 1  2.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750.0  23.0   10.0
# 2  3.0  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950.0  24.0    9.0
# 3  4.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950.0  26.0    7.0
# 4  5.0     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750.0  30.0    3.0
#
#     Mfg-Y       KM Fuel_Type    HP  Met_Color  Automatic      cc  Doors  \
# 0  2002.0  46986.0    Diesel  90.0        1.0        0.0  2000.0    3.0
# 1  2002.0  72937.0    Diesel  90.0        1.0        0.0  2000.0    3.0
# 2  2002.0  41711.0    Diesel  90.0        1.0        0.0  2000.0    3.0
# 3  2002.0  48000.0    Diesel  90.0        0.0        0.0  2000.0    3.0
# 4  2002.0  38500.0    Diesel  90.0        0.0        0.0  2000.0    3.0
#
#    Cylinders  Gears  Quarterly_Tax  Weight  ABS  Airbag_1  Airbag_2
# ...

# %%
df_new = df1.iloc[:, [0,1,2,7]]

# %%
df_new.head()
# Out:
#     Id                                           Model    Price Fuel_Type
# 0  1.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500.0    Diesel
# 1  2.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750.0    Diesel
# 2  3.0  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950.0    Diesel
# 3  4.0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950.0    Diesel
# 4  5.0     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750.0    Diesel

# %%
df_new = df1[['Model', 'Price']]

# %%
df_new.head()
# Out:
#                                             Model    Price
# 0   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500.0
# 1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750.0
# 2  ?TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950.0
# 3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950.0
# 4     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750.0

# %%
df500=df1.loc[0:500]

# %%
df500.shape
# Out:
# (501, 20)

# %%
df1.loc[df1['Price'] >= 25000]
# Out:
#         Id                                          Model    Price  Age  \
# 109  111.0  ?TOYOTA Corolla VERSO 2.0 D4D SOL (7) BNS MPV  32500.0  4.0
# 110  112.0       TOYOTA Corolla VERSO 2.0 D4D SOL (7) MPV  31000.0  4.0
# 111  113.0       TOYOTA Corolla VERSO 2.0 D4D SOL (7) MPV  31275.0  4.0
#
#      Mfg-M   Mfg-Y      KM Fuel_Type     HP  Met_Color  Automatic      cc  \
# 109    5.0  2004.0     NaN    Diesel    NaN        0.0        0.0  2000.0
# 110    NaN     NaN     NaN    Diesel  116.0        NaN        0.0  2000.0
# 111    5.0     NaN  1500.0    Diesel  116.0        1.0        NaN  2000.0
#
#      Doors  Cylinders  Gears  Quarterly_Tax  Weight  ABS  Airbag_1  Airbag_2
# 109    5.0        4.0    5.0          283.0  1480.0  1.0       1.0       1.0
# 110    5.0        4.0    5.0          283.0  1480.0  1.0       1.0       1.0
# 111    5.0        4.0    5.0          283.0  1480.0  1.0       1.0       1.0

# %%
df1.isnull().sample(10)
# Out:
#          Id  Model  Price    Age  Mfg-M  Mfg-Y     KM  Fuel_Type     HP  \
# 868   False   True  False  False   True  False  False      False   True
# 786   False  False  False  False  False  False  False      False  False
# 1071  False  False  False  False  False   True   True       True  False
# 946   False  False   True   True  False  False  False      False  False
# 1040  False  False  False  False  False  False  False      False  False
# 1309  False  False  False  False  False  False  False      False  False
# 85    False  False  False  False  False  False  False      False  False
# 277   False  False  False  False  False  False  False      False  False
# 1414  False  False  False  False  False  False  False      False  False
# 1215  False   True  False  False  False  False  False      False  False
#
#       Met_Color  Automatic     cc  Doors  Cylinders  Gears  Quarterly_Tax  \
# 868       False      False  False  False      False  False          False
# ...

# %%
df1['Airbag_1'].isnull().sum()
# Out:
# 128

# %%
df1.isnull().sum()
# Out:
# Id                 8
# Model             20
# Price             23
# Age               37
# Mfg-M             38
# Mfg-Y             45
# KM                52
# Fuel_Type         54
# HP                42
# Met_Color         34
# Automatic         19
# cc                32
# Doors             15
# Cylinders         24
# Gears             16
# Quarterly_Tax     27
# Weight            22
# ABS               11
# Airbag_1         128
# Airbag_2           7
# dtype: int64

# %%
c1=(df1['Id'].isnull().sum()/len(df1))*100
c2=(df1['Model'].isnull().sum()/len(df1))*100
c3=(df1['Price'].isnull().sum()/len(df1))*100
c4=(df1['Age'].isnull().sum()/len(df1))*100
c5=(df1['Mfg-M'].isnull().sum()/len(df1))*100
c6=(df1['Mfg-Y'].isnull().sum()/len(df1))*100
c7=(df1['KM'].isnull().sum()/len(df1))*100
c8=(df1['Fuel_Type'].isnull().sum()/len(df1))*100
c9=(df1['HP'].isnull().sum()/len(df1))*100
c10=(df1['Met_Color'].isnull().sum()/len(df1))*100
c11=(df1['Automatic'].isnull().sum()/len(df1))*100
c12=(df1['cc'].isnull().sum()/len(df1))*100
c13=(df1['Doors'].isnull().sum()/len(df1))*100
c14=(df1['Cylinders'].isnull().sum()/len(df1))*100
c15=(df1['Gears'].isnull().sum()/len(df1))*100
c16=(df1['Quarterly_Tax'].isnull().sum()/len(df1))*100
c17=(df1['Weight'].isnull().sum()/len(df1))*100
c18=(df1['ABS'].isnull().sum()/len(df1))*100
c19=(df1['Airbag_1'].isnull().sum()/len(df1))*100
c20=(df1['Airbag_2'].isnull().sum()/len(df1))*100

# %%
data = {
    'Columns': ['Id', 'Model', 'Price', 'Age', 'Mfg-M', 'Mfg-Y', 'KM', 'Fuel_Type', 'HP', 'Met_Color',
               'Automatic', 'cc', 'Doors', 'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'ABS', 'Airbag_1', 'Airbag_2'],
    'Percentage': [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c20]
}

perc = pd.DataFrame(data)
perc
# Out:
#           Columns  Percentage
# 0              Id    0.557103
# 1           Model    1.392758
# 2           Price    1.601671
# 3             Age    2.576602
# 4           Mfg-M    2.646240
# 5           Mfg-Y    3.133705
# 6              KM    3.621170
# 7       Fuel_Type    3.760446
# 8              HP    2.924791
# 9       Met_Color    2.367688
# 10      Automatic    1.323120
# 11             cc    2.228412
# 12          Doors    1.044568
# 13      Cylinders    1.671309
# 14          Gears    1.114206
# 15  Quarterly_Tax    1.880223
# 16         Weight    1.532033
# 17            ABS    0.766017
# 18       Airbag_1    8.913649
# 19       Airbag_2    0.487465

# %%
# df2=df1.dropna()

# %%
df1.drop(columns=['Airbag_1','Airbag_2'],inplace=True)

# %%
columns = ['Id', 'Model', 'Price', 'Automatic','Gears','ABS','Doors','Met_Color','Mfg-M','Mfg-Y']

df1.dropna(subset=columns, how='any', inplace=True)

# %%
no_null=df1[df1.notnull().all(axis=1)]
A=no_null['Age'].mean()
km=no_null['KM'].mean()
Q=no_null['Quarterly_Tax'].mean()
w=no_null['Weight'].mean()

# %%
data = {
    'Columns': [ 'Age',  'KM', 'Quarterly_Tax', 'Weight'],
    'Mean': [A,km,Q,w]
}

M = pd.DataFrame(data)
M
# Out:
#          Columns          Mean
# 0            Age     55.604165
# 1             KM  70340.987751
# 2  Quarterly_Tax     88.276959
# 3         Weight   1070.905066

# %%
df1.isnull().sum()
# Out:
# Id                0
# Model             0
# Price             0
# Age              21
# Mfg-M             0
# Mfg-Y             0
# KM               33
# Fuel_Type        45
# HP               31
# Met_Color         0
# Automatic         0
# cc               16
# Doors             0
# Cylinders        18
# Gears             0
# Quarterly_Tax    22
# Weight           21
# ABS               0
# dtype: int64

# %%
rows = df1[df1.notnull().all(axis=1)]
rows.sample(5)
# Out:
#           Id                                              Model    Price  \
# 431    434.0  TOYOTA Corolla 1.4 16V VVT I HATCHB SOL 2/3-Doors  10950.0
# 49      50.0  TOYOTA Corolla 1.8 16V VVTLI 5DR T SPORT 4/5-D...  21950.0
# 737    741.0  TOYOTA Corolla 1.6 16V LIFTB LINEA TERRA 4/5-D...   8750.0
# 729    733.0  TOYOTA Corolla 1.6 16V SEDAN LINEA TERRA 4/5-D...   8950.0
# 1121  1127.0          TOYOTA Corolla 1.3 16V HATCHB S 2/3-Doors   7750.0
#
#        Age  Mfg-M   Mfg-Y        KM Fuel_Type     HP  Met_Color  Automatic  \
# 431   50.0    7.0  2000.0   82735.0    Petrol   97.0        1.0        0.0
# 49    31.0    2.0  2002.0   64982.0    Petrol  192.0        1.0        0.0
# 737   62.0    7.0  1999.0   83908.0    Petrol  110.0        1.0        0.0
# 729   68.0    1.0  1999.0   86714.0    Petrol  110.0        1.0        0.0
# 1121  73.0    8.0  1998.0  111602.0    Petrol   86.0        1.0        0.0
#
#           cc  Doors  Cylinders  Gears  Quarterly_Tax  Weight  ABS
# ...

# %%
rows.isnull().sum()
# Out:
# Id               0
# Model            0
# Price            0
# Age              0
# Mfg-M            0
# Mfg-Y            0
# KM               0
# Fuel_Type        0
# HP               0
# Met_Color        0
# Automatic        0
# cc               0
# Doors            0
# Cylinders        0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# ABS              0
# dtype: int64

# %%
df1['Age']=df1['Age'].fillna(df1['Age'].mean())
df1['KM']=df1['KM'].fillna(df1['KM'].mean())
df1['Quarterly_Tax']=df1['Quarterly_Tax'].fillna(df1['Quarterly_Tax'].mean())
df1['Weight']=df1['Weight'].fillna(df1['Weight'].mean())

# %%
df1.isnull().sum()
# Out:
# Id                0
# Model             0
# Price             0
# Age               0
# Mfg-M             0
# Mfg-Y             0
# KM                0
# Fuel_Type        45
# HP               31
# Met_Color         0
# Automatic         0
# cc               16
# Doors             0
# Cylinders        18
# Gears             0
# Quarterly_Tax     0
# Weight            0
# ABS               0
# dtype: int64

# %%
df1.sample(5)
# Out:
#         Id                                              Model    Price   Age  \
# 639  643.0  TOYOTA Corolla 2.0 DSL SEDAN LINEA TERRA 4/5-D...   9950.0  66.0
# 117  119.0  TOYOTA Corolla 1.6 16V VVT I 3DR TERRA COMFORT...  17900.0   7.0
# 564  568.0  ?TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3...   9750.0  56.0
# 293  295.0  TOYOTA Corolla 1.6 16V VVT I LIFTB LUNA 4/5-Doors  12295.0  33.0
# 291  293.0  TOYOTA Corolla 1.6 16V VVT I LIFTB LUNA 4/5-Doors  13875.0  39.0
#
#      Mfg-M   Mfg-Y        KM Fuel_Type     HP  Met_Color  Automatic      cc  \
# 639    3.0  1999.0  120000.0    Diesel   72.0        0.0        0.0  2000.0
# 117    2.0  2004.0       1.0    Petrol  110.0        1.0        0.0  1600.0
# 564    1.0  2000.0   37461.0    Petrol   97.0        0.0        0.0  1400.0
# 293   12.0  2001.0   42823.0    Petrol  110.0        1.0        0.0  1600.0
# 291    6.0  2001.0   43254.0    Petrol  110.0        1.0        0.0  1600.0
#
# ...

# %%
df1['Age']=df1['Age'].fillna(df1['Age'].median())
df1['KM']=df1['KM'].fillna(df1['KM'].median())
df1['Quarterly_Tax']=df1['Quarterly_Tax'].fillna(df1['Quarterly_Tax'].median())
df1['Weight']=df1['Weight'].fillna(df1['Weight'].median())

# %%
df1.sample(5)
# Out:
#         Id                                              Model    Price   Age  \
# 588  592.0        TOYOTA Corolla 1.4 HB LINEA TERRA 2/3-Doors   9950.0  48.0
# 393  396.0                   TOYOTA Corolla 1.8D Stationwagen   4450.0  56.0
# 292  294.0  TOYOTA Corolla 1.6 16V HATCHB LINEA TERRA 2/3-...  10500.0  35.0
# 101  102.0  ?TOYOTA Corolla 1.4 16V VVT I 3DR TERRA COMFOR...  16250.0  19.0
# 460  463.0  TOYOTA Corolla 1.4 16V VVT I HATCHB TERRA 2/3-...   9500.0  55.0
#
#      Mfg-M   Mfg-Y        KM Fuel_Type     HP  Met_Color  Automatic      cc  \
# 588    9.0  2000.0   28656.0    Petrol   97.0        0.0        0.0  1400.0
# 393    1.0  2000.0  129155.0    Diesel   69.0        0.0        0.0  1800.0
# 292   10.0  2001.0   43000.0    Petrol  110.0        0.0        0.0  1600.0
# 101    2.0  2003.0   19200.0    Petrol   97.0        1.0        0.0  1400.0
# 460    2.0  2000.0   69813.0    Petrol   97.0        1.0        0.0  1400.0
#
# ...
